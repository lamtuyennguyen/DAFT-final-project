# %%
# import relevant libraries
import numpy as np
import pandas as pd

# %%
# load quality of life dataset
quality_of_life = pd.read_csv('../data/quality_of_life_index_2020.csv')
quality_of_life
# Out:
#         Country  Quality of Life Index  Purchasing Power Index  Safety Index  \
# 0       Denmark                 192.67                  100.88         74.90
# 1   Switzerland                 192.01                  119.53         78.40
# 2       Finland                 190.22                   99.93         76.68
# 3     Australia                 186.21                  107.31         58.64
# 4   Netherlands                 183.67                   90.73         72.38
# ..          ...                    ...                     ...           ...
# 75    Sri Lanka                  85.16                   24.45         59.78
# 76         Iran                  74.14                   22.69         50.75
# 77        Kenya                  70.56                   27.32         38.34
# 78   Bangladesh                  70.03                   33.21         36.06
# 79      Nigeria                  55.65                   13.52         36.23
#
# ...

# %%
# check countries with indices existed
selected_indices.index
# Out:
# Index(['Denmark', 'Switzerland', 'Finland', 'Australia', 'Netherlands',
#        'Austria', 'Iceland', 'New Zealand', 'Germany', 'Estonia', 'Sweden',
#        'Norway', 'Slovenia', 'United States', 'Spain', 'Japan', 'Oman',
#        'Canada', 'Portugal', 'United Kingdom', 'Qatar', 'Lithuania', 'Croatia',
#        'United Arab Emirates', 'Czech Republic', 'France', 'Ireland',
#        'Belgium', 'Slovakia', 'Saudi Arabia', 'Latvia', 'Israel', 'Cyprus',
#        'Singapore', 'Taiwan', 'Poland', 'Italy', 'South Korea', 'Belarus',
#        'Greece', 'Romania', 'South Africa', 'Bulgaria', 'Hungary', 'Turkey',
#        'Uruguay', 'Ecuador', 'Bosnia And Herzegovina', 'Chile', 'Mexico',
#        'Malaysia', 'Serbia', 'Georgia', 'Kuwait', 'Argentina', 'Jordan',
#        'North Macedonia', 'India', 'Panama', 'Lebanon', 'Colombia', 'Brazil',
#        'Morocco', 'Pakistan', 'Ukraine', 'China', 'Russia', 'Thailand',
#        'Hong Kong', 'Indonesia', 'Kazakhstan', 'Vietnam', 'Egypt', 'Peru',
# ...

# %%
# drop irrelevant columns
selected_indices = quality_of_life.drop(columns=['Cost of Living Index', 'Property Price to Income Ratio'])
selected_indices
# Out:
#         Country  Quality of Life Index  Purchasing Power Index  Safety Index  \
# 0       Denmark                 192.67                  100.88         74.90
# 1   Switzerland                 192.01                  119.53         78.40
# 2       Finland                 190.22                   99.93         76.68
# 3     Australia                 186.21                  107.31         58.64
# 4   Netherlands                 183.67                   90.73         72.38
# ..          ...                    ...                     ...           ...
# 75    Sri Lanka                  85.16                   24.45         59.78
# 76         Iran                  74.14                   22.69         50.75
# 77        Kenya                  70.56                   27.32         38.34
# 78   Bangladesh                  70.03                   33.21         36.06
# 79      Nigeria                  55.65                   13.52         36.23
#
# ...

# %%
# load cost of living dataset
cost_of_living = pd.read_csv('../data/cost_of_living_index_2020.csv')
cost_of_living
# Out:
#          Country  Cost of Living Index  Rent Index  \
# 0    Switzerland                122.40       50.25
# 1         Norway                101.43       36.15
# 2        Iceland                100.48       46.95
# 3          Japan                 83.35       25.97
# 4        Denmark                 83.00       31.92
# ..           ...                   ...         ...
# 127   Uzbekistan                 26.01        7.54
# 128        Syria                 25.31        5.68
# 129        India                 24.58        5.68
# 130  Afghanistan                 24.24        4.03
# 131     Pakistan                 21.98        4.59
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                             87.89           120.27                  123.01
# 1                             70.21            91.14                  109.28
# 2                             74.88            86.89                  113.74
# ...

# %%
# keep relevant columns
selected_cost_of_living = cost_of_living[['Country', 'Cost of Living Plus Rent Index']]
selected_cost_of_living
# Out:
#          Country  Cost of Living Plus Rent Index
# 0    Switzerland                           87.89
# 1         Norway                           70.21
# 2        Iceland                           74.88
# 3          Japan                           55.90
# 4        Denmark                           58.57
# ..           ...                             ...
# 127   Uzbekistan                           17.18
# 128        Syria                           15.92
# 129        India                           15.54
# 130  Afghanistan                           14.58
# 131     Pakistan                           13.66
#
# [132 rows x 2 columns]

# %%
# join datasets with relevant columns
selected_indices = selected_indices.set_index('Country').join(selected_cost_of_living.set_index('Country'))
selected_indices
# Out:
#              Quality of Life Index  Purchasing Power Index  Safety Index  \
# Country
# Denmark                     192.67                  100.88         74.90
# Switzerland                 192.01                  119.53         78.40
# Finland                     190.22                   99.93         76.68
# Australia                   186.21                  107.31         58.64
# Netherlands                 183.67                   90.73         72.38
# ...                            ...                     ...           ...
# Sri Lanka                    85.16                   24.45         59.78
# Iran                         74.14                   22.69         50.75
# Kenya                        70.56                   27.32         38.34
# Bangladesh                   70.03                   33.21         36.06
# Nigeria                      55.65                   13.52         36.23
#
#              Health Care Index  Traffic Commute Time Index  Pollution Index  \
# ...

# %%
# load passport index dataset
passport_index = pd.read_csv('../data/passport_index_2015_2020.csv')
passport_index
# Out:
#      region_name  score_2020_Covid  score_2020  score_2019  score_2018  \
# 0        Belgium               112         124         170       164.0
# 1        Finland               112         124         172       165.0
# 2        Austria               112         125         171       164.0
# 3     Luxembourg               112         125         172       165.0
# 4          Spain               112         124         172       165.0
# ..           ...               ...         ...         ...         ...
# 203        Yemen                32          35          44        39.0
# 204      Somalia                32          34          41        38.0
# 205        Syria                31          33          40        36.0
# 206  Afghanistan                28          30          35        29.0
# 207         Iraq                27          30          37        32.0
#
#      score_2017  score_2016  score_2015
# 0           121       154.0       156.0
# ...

# %%
# keep relevant score
selected_passport_index = passport_index[['region_name', 'score_2020']]
selected_passport_index
# Out:
#      region_name  score_2020
# 0        Belgium         124
# 1        Finland         124
# 2        Austria         125
# 3     Luxembourg         125
# 4          Spain         124
# ..           ...         ...
# 203        Yemen          35
# 204      Somalia          34
# 205        Syria          33
# 206  Afghanistan          30
# 207         Iraq          30
#
# [208 rows x 2 columns]

# %%
# rename column name
selected_passport_index = selected_passport_index.rename({'region_name': 'Country', 'score_2020': 'Passport Index'}, axis=1)
selected_passport_index
# Out:
#          Country  Passport Index
# 0        Belgium             124
# 1        Finland             124
# 2        Austria             125
# 3     Luxembourg             125
# 4          Spain             124
# ..           ...             ...
# 203        Yemen              35
# 204      Somalia              34
# 205        Syria              33
# 206  Afghanistan              30
# 207         Iraq              30
#
# [208 rows x 2 columns]

# %%
# join passport index to main dataframe
selected_indices = selected_indices.join(selected_passport_index.set_index('Country'), on = 'Country')
selected_indices
# Out:
#              Quality of Life Index  Purchasing Power Index  Safety Index  \
# Country
# Denmark                     192.67                  100.88         74.90
# Switzerland                 192.01                  119.53         78.40
# Finland                     190.22                   99.93         76.68
# Australia                   186.21                  107.31         58.64
# Netherlands                 183.67                   90.73         72.38
# ...                            ...                     ...           ...
# Sri Lanka                    85.16                   24.45         59.78
# Iran                         74.14                   22.69         50.75
# Kenya                        70.56                   27.32         38.34
# Bangladesh                   70.03                   33.21         36.06
# Nigeria                      55.65                   13.52         36.23
#
#              Health Care Index  Traffic Commute Time Index  Pollution Index  \
# ...

# %%
# load ease of doing business dataset
doing_business = pd.read_excel('../data/ease_of_doing_business.xlsx', header = 9)
doing_business
# Out:
#      Economy           Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0        NaN          Afghanistan        44.2        44.1
# 1        NaN              Albania        67.0        67.7
# 2        NaN              Algeria        48.5        48.6
# 3        NaN               Angola        41.2        41.3
# 4        NaN  Antigua and Barbuda        59.9        60.3
# ..       ...                  ...         ...         ...
# 208      NaN              Vietnam        68.6        69.8
# 209      NaN   West Bank and Gaza        59.7        60.0
# 210      NaN          Yemen, Rep.        30.7        31.8
# 211      NaN               Zambia        65.7        66.9
# 212      NaN             Zimbabwe        50.5        54.5
#
# [213 rows x 4 columns]

# %%
# keep relevant columns
doing_business = doing_business[['Unnamed: 1', 'Unnamed: 3']]
doing_business
# Out:
#               Unnamed: 1  Unnamed: 3
# 0            Afghanistan        44.1
# 1                Albania        67.7
# 2                Algeria        48.6
# 3                 Angola        41.3
# 4    Antigua and Barbuda        60.3
# ..                   ...         ...
# 208              Vietnam        69.8
# 209   West Bank and Gaza        60.0
# 210          Yemen, Rep.        31.8
# 211               Zambia        66.9
# 212             Zimbabwe        54.5
#
# [213 rows x 2 columns]

# %%
# rename columns
doing_business = doing_business.rename({'Unnamed: 1': 'Country', 'Unnamed: 3': 'Ease of Doing Business Index'}, axis=1)
doing_business
# Out:
#                  Country  Ease of Doing Business Index
# 0            Afghanistan                          44.1
# 1                Albania                          67.7
# 2                Algeria                          48.6
# 3                 Angola                          41.3
# 4    Antigua and Barbuda                          60.3
# ..                   ...                           ...
# 208              Vietnam                          69.8
# 209   West Bank and Gaza                          60.0
# 210          Yemen, Rep.                          31.8
# 211               Zambia                          66.9
# 212             Zimbabwe                          54.5
#
# [213 rows x 2 columns]

# %%
# join ease of doing business index to main dataframe
selected_indices = selected_indices.join(doing_business.set_index('Country'), on = 'Country')
selected_indices
# Out:
#              Quality of Life Index  Purchasing Power Index  Safety Index  \
# Country
# Denmark                     192.67                  100.88         74.90
# Switzerland                 192.01                  119.53         78.40
# Finland                     190.22                   99.93         76.68
# Australia                   186.21                  107.31         58.64
# Netherlands                 183.67                   90.73         72.38
# ...                            ...                     ...           ...
# Sri Lanka                    85.16                   24.45         59.78
# Iran                         74.14                   22.69         50.75
# Kenya                        70.56                   27.32         38.34
# Bangladesh                   70.03                   33.21         36.06
# Nigeria                      55.65                   13.52         36.23
#
#              Health Care Index  Traffic Commute Time Index  Pollution Index  \
# ...

# %%
# load corruption index dataset
corruption = pd.read_excel('../data/corruption_perception_index_2019.xlsx', header = 2)
corruption
# Out:
#          Country ISO3 Region  CPI score 2019  Rank  standard error   \
# 0        Denmark  DNK  WE/EU              87     1         2.542474
# 1    New Zealand  NZL     AP              87     1         2.286490
# 2        Finland  FIN  WE/EU              86     3         2.924511
# 3      Singapore  SGP     AP              85     4         2.048400
# 4         Sweden  SWE  WE/EU              85     4         1.977693
# ..           ...  ...    ...             ...   ...              ...
# 175    Venezuela  VEN    AME              16   173         2.048858
# 176        Yemen  YEM   MENA              15   177         1.885994
# 177        Syria  SYR   MENA              13   178         1.921515
# 178  South Sudan  SSD    SSA              12   179         1.263942
# 179      Somalia  SOM    SSA               9   180         1.740826
#
#      Number of sources   Lower CI  Upper CI  African Development Bank CPIA  \
# ...

# %%
# keep relevant columns
corruption = corruption[['Country', 'CPI score 2019']]
corruption
# Out:
#          Country  CPI score 2019
# 0        Denmark              87
# 1    New Zealand              87
# 2        Finland              86
# 3      Singapore              85
# 4         Sweden              85
# ..           ...             ...
# 175    Venezuela              16
# 176        Yemen              15
# 177        Syria              13
# 178  South Sudan              12
# 179      Somalia               9
#
# [180 rows x 2 columns]

# %%
# rename columns
corruption = corruption.rename({'CPI score 2019': 'Corruption Index'}, axis=1)
corruption
# Out:
#          Country  Corruption Index
# 0        Denmark                87
# 1    New Zealand                87
# 2        Finland                86
# 3      Singapore                85
# 4         Sweden                85
# ..           ...               ...
# 175    Venezuela                16
# 176        Yemen                15
# 177        Syria                13
# 178  South Sudan                12
# 179      Somalia                 9
#
# [180 rows x 2 columns]

# %%
# join corruption index to main dataframe
selected_indices = selected_indices.join(corruption.set_index('Country'), on = 'Country')
selected_indices
# Out:
#              Quality of Life Index  Purchasing Power Index  Safety Index  \
# Country
# Denmark                     192.67                  100.88         74.90
# Switzerland                 192.01                  119.53         78.40
# Finland                     190.22                   99.93         76.68
# Australia                   186.21                  107.31         58.64
# Netherlands                 183.67                   90.73         72.38
# ...                            ...                     ...           ...
# Sri Lanka                    85.16                   24.45         59.78
# Iran                         74.14                   22.69         50.75
# Kenya                        70.56                   27.32         38.34
# Bangladesh                   70.03                   33.21         36.06
# Nigeria                      55.65                   13.52         36.23
#
#              Health Care Index  Traffic Commute Time Index  Pollution Index  \
# ...

# %%
# load population density dataset
population_density = pd.read_csv('../data/population_density.csv')
population_density
# Out:
#     Rank Country (or dependent territory)   Area km2  Area mi2 Population  \
# 0      –                            Macau      32.90        13   6,76,100
# 1      1                           Monaco       2.02      0.78     38,300
# 2      2                        Singapore      722.5       279  57,03,600
# 3      –                        Hong Kong      1,106       427  75,00,700
# 4      –                   Gibraltar (UK)        6.8       2.6     33,701
# ..   ...                              ...        ...       ...        ...
# 246  194                         Mongolia  15,64,100  6,03,902  30,00,000
# 247    –            Pitcairn Islands (UK)       47.3        18         56
# 248    –            Falkland Islands (UK)     12,173     4,700      2,563
# 249    –  Svalbard and Jan Mayen (Norway)     61,399    23,706      2,655
# 250    –              Greenland (Denmark)  21,66,000  8,36,297     55,877
#
#     Density pop./km2 Density pop./mi2                Date  \
# ...

# %%
# select relevant columns
selected_population_density = population_density[['Country (or dependent territory)', 'Density pop./km2']]
selected_population_density
# Out:
#     Country (or dependent territory) Density pop./km2
# 0                              Macau           20,550
# 1                             Monaco           18,960
# 2                          Singapore            7,894
# 3                          Hong Kong            6,782
# 4                     Gibraltar (UK)            4,956
# ..                               ...              ...
# 246                         Mongolia              1.9
# 247            Pitcairn Islands (UK)              1.2
# 248            Falkland Islands (UK)             0.21
# 249  Svalbard and Jan Mayen (Norway)             0.04
# 250              Greenland (Denmark)             0.03
#
# [251 rows x 2 columns]

# %%
# rename columns
selected_population_density = selected_population_density.rename({'Country (or dependent territory)': 'Country', 'Density pop./km2': 'Population Density' }, axis=1)
selected_population_density
# Out:
#                              Country Population Density
# 0                              Macau             20,550
# 1                             Monaco             18,960
# 2                          Singapore              7,894
# 3                          Hong Kong              6,782
# 4                     Gibraltar (UK)              4,956
# ..                               ...                ...
# 246                         Mongolia                1.9
# 247            Pitcairn Islands (UK)                1.2
# 248            Falkland Islands (UK)               0.21
# 249  Svalbard and Jan Mayen (Norway)               0.04
# 250              Greenland (Denmark)               0.03
#
# [251 rows x 2 columns]

# %%
# join population density to main dataframe
selected_indices = selected_indices.join(selected_population_density.set_index('Country'), on = 'Country')
selected_indices
# Out:
#              Quality of Life Index  Purchasing Power Index  Safety Index  \
# Country
# Denmark                     192.67                  100.88         74.90
# Switzerland                 192.01                  119.53         78.40
# Finland                     190.22                   99.93         76.68
# Australia                   186.21                  107.31         58.64
# Netherlands                 183.67                   90.73         72.38
# ...                            ...                     ...           ...
# Sri Lanka                    85.16                   24.45         59.78
# Iran                         74.14                   22.69         50.75
# Kenya                        70.56                   27.32         38.34
# Bangladesh                   70.03                   33.21         36.06
# Nigeria                      55.65                   13.52         36.23
#
#              Health Care Index  Traffic Commute Time Index  Pollution Index  \
# ...

# %%
covid = pd.read_csv('../data/covid_cases_september2020.csv')
covid
# Out:
#               country  num_of_infections  total_population
# 0                 USA            7361611         331478677
# 1               India            6145291        1383308133
# 2              Brazil            4748327         212929158
# 3              Russia            1159573         145949954
# 4            Colombia             818203          51014752
# ..                ...                ...               ...
# 210  Falkland Islands                 13              3504
# 211      Vatican City                 12               801
# 212    Western Sahara                 10            600815
# 213        MS Zaandam                  9                 0
# 214          Anguilla                  3             15036
#
# [215 rows x 3 columns]

# %%
# drop irrelevant columns                          
selected_covid = covid.drop(columns=['total_population']) 
selected_covid
# Out:
#               country  num_of_infections
# 0                 USA            7361611
# 1               India            6145291
# 2              Brazil            4748327
# 3              Russia            1159573
# 4            Colombia             818203
# ..                ...                ...
# 210  Falkland Islands                 13
# 211      Vatican City                 12
# 212    Western Sahara                 10
# 213        MS Zaandam                  9
# 214          Anguilla                  3
#
# [215 rows x 2 columns]

# %%
# rename columns
selected_covid = selected_covid.rename({'country': 'Country', 'num_of_infections': 'Current Covid Cases' }, axis=1)
selected_covid
# Out:
#               Country  Current Covid Cases
# 0                 USA              7361611
# 1               India              6145291
# 2              Brazil              4748327
# 3              Russia              1159573
# 4            Colombia               818203
# ..                ...                  ...
# 210  Falkland Islands                   13
# 211      Vatican City                   12
# 212    Western Sahara                   10
# 213        MS Zaandam                    9
# 214          Anguilla                    3
#
# [215 rows x 2 columns]

# %%
# join covid cases to main dataframe
selected_indices = selected_indices.join(selected_covid.set_index('Country'), on = 'Country')
selected_indices
# Out:
#              Quality of Life Index  Purchasing Power Index  Safety Index  \
# Country
# Denmark                     192.67                  100.88         74.90
# Switzerland                 192.01                  119.53         78.40
# Finland                     190.22                   99.93         76.68
# Australia                   186.21                  107.31         58.64
# Netherlands                 183.67                   90.73         72.38
# ...                            ...                     ...           ...
# Sri Lanka                    85.16                   24.45         59.78
# Iran                         74.14                   22.69         50.75
# Kenya                        70.56                   27.32         38.34
# Bangladesh                   70.03                   33.21         36.06
# Nigeria                      55.65                   13.52         36.23
#
#              Health Care Index  Traffic Commute Time Index  Pollution Index  \
# ...

# %%
# load happiness dataset
happiness = pd.read_csv('../data/happiness_score_2020.csv')
happiness
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# ...

# %%
# select relevant columns
happiness = happiness[['Country name', 'Ladder score']]
happiness
# Out:
#                  Country name  Ladder score
# 0                     Finland        7.8087
# 1                     Denmark        7.6456
# 2                 Switzerland        7.5599
# 3                     Iceland        7.5045
# 4                      Norway        7.4880
# ..                        ...           ...
# 148  Central African Republic        3.4759
# 149                    Rwanda        3.3123
# 150                  Zimbabwe        3.2992
# 151               South Sudan        2.8166
# 152               Afghanistan        2.5669
#
# [153 rows x 2 columns]

# %%
# rename columns
happiness = happiness.rename({'Country name': 'Country', 'Ladder score': 'Happiness Score' }, axis=1)
happiness
# Out:
#                       Country  Happiness Score
# 0                     Finland           7.8087
# 1                     Denmark           7.6456
# 2                 Switzerland           7.5599
# 3                     Iceland           7.5045
# 4                      Norway           7.4880
# ..                        ...              ...
# 148  Central African Republic           3.4759
# 149                    Rwanda           3.3123
# 150                  Zimbabwe           3.2992
# 151               South Sudan           2.8166
# 152               Afghanistan           2.5669
#
# [153 rows x 2 columns]

# %%
# join happiness score to main dataframe
selected_indices = selected_indices.join(happiness.set_index('Country'), on = 'Country')
selected_indices
# Out:
#              Quality of Life Index  Purchasing Power Index  Safety Index  \
# Country
# Denmark                     192.67                  100.88         74.90
# Switzerland                 192.01                  119.53         78.40
# Finland                     190.22                   99.93         76.68
# Australia                   186.21                  107.31         58.64
# Netherlands                 183.67                   90.73         72.38
# ...                            ...                     ...           ...
# Sri Lanka                    85.16                   24.45         59.78
# Iran                         74.14                   22.69         50.75
# Kenya                        70.56                   27.32         38.34
# Bangladesh                   70.03                   33.21         36.06
# Nigeria                      55.65                   13.52         36.23
#
#              Health Care Index  Traffic Commute Time Index  Pollution Index  \
# ...

# %%
# save relevant dataframe
selected_indices.to_csv('../data/merged_dataframe.csv')
